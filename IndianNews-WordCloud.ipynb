# %%
from newscatcher import Newscatcher
from itertools import chain 
import pandas as pd

# %%
ht = Newscatcher('hindustantimes.com')
a = ht.headlines[:5]

# %%
hindu = Newscatcher('thehindu.com')
b = hindu.headlines[:5]

# %%
toi = Newscatcher('timesofindia.indiatimes.com')
c = toi.headlines[:5]

# %%
express = Newscatcher('indianexpress.com')
d = express.headlines[:5]

# %%
tribune = Newscatcher('tribuneindia.com')
e = tribune.headlines[:5]

# %%
et = Newscatcher('economictimes.indiatimes.com')
f = et.headlines[:5]

# %%
deccan = Newscatcher('deccanchronicle.com')
g = deccan.headlines[:5]

# %%
#Adding all the lists using a chain command
my_list = list(chain(a, b, c, d, e, f, g)) 

#Converting the list into a Dataframe
df = pd.DataFrame(my_list) 

#Adding a column name which will be used in making the Word Cloud
frame = pd.DataFrame(df.values, columns =["Headline"])

# %%
#Making a WordCloud out of a dataframe
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = frame.Headline.values
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
